# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine.csv')

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
df.tail()
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
#      OD280  Proline
# 173   1.74      740
# 174   1.56      750
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.corr()
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
correlation_matrix = df.corr(method='pearson')  # or 'spearman'

threshold = 0.5
filtered_corr = correlation_matrix.where(abs(correlation_matrix) > threshold)

# Visualizing with a heatmap
plt.figure(figsize=(10,8))
sns.heatmap(filtered_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
from sklearn.feature_selection import VarianceThreshold

# Set a variance threshold (e.g., 0.1)
selector = VarianceThreshold(threshold=0.1)
selector.fit(df)

# Get the selected features
selected_features = df.columns[selector.get_support()]
print(selected_features)
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash_Alcanity', 'Magnesium', 'Total_Phenols',
#        'Flavanoids', 'Proanthocyanins', 'Color_Intensity', 'OD280', 'Proline'],
#       dtype='object')

# %%
new_df = df[selected_features]

# %%
new_df
# Out:
#      Alcohol  Malic_Acid  Ash_Alcanity  Magnesium  Total_Phenols  Flavanoids  \
# 0      14.23        1.71          15.6        127           2.80        3.06
# 1      13.20        1.78          11.2        100           2.65        2.76
# 2      13.16        2.36          18.6        101           2.80        3.24
# 3      14.37        1.95          16.8        113           3.85        3.49
# 4      13.24        2.59          21.0        118           2.80        2.69
# ..       ...         ...           ...        ...            ...         ...
# 173    13.71        5.65          20.5         95           1.68        0.61
# 174    13.40        3.91          23.0        102           1.80        0.75
# 175    13.27        4.28          20.0        120           1.59        0.69
# 176    13.17        2.59          20.0        120           1.65        0.68
# 177    14.13        4.10          24.5         96           2.05        0.76
#
# ...

# %%
correlation_matrix = new_df.corr(method='pearson')  # or 'spearman'

threshold = 0.5
filtered_corr = correlation_matrix.where(abs(correlation_matrix) > threshold)

# Visualizing with a heatmap
plt.figure(figsize=(10,8))
sns.heatmap(filtered_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
plt.scatter(new_df['Alcohol'],new_df['Proline'])
plt.plot()
# Out:
# []

# %%
plt.scatter(new_df['Total_Phenols'],new_df['OD280'])
plt.plot()
# Out:
# []

# %%
plt.scatter(new_df['Total_Phenols'],new_df['Flavanoids'])
plt.plot()
# Out:
# []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Specify the columns you want to include in the pair plot
selected_columns = ['Alcohol', 'Total_Phenols', 'Flavanoids', 'Proanthocyanins', 'OD280','Proline']

# Create the pair plot for selected columns
sns.pairplot(df[selected_columns])

# Show the plot
plt.show()

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df['Proline'].unique()
# Out:
# array([1065, 1050, 1185, 1480,  735, 1450, 1290, 1295, 1045, 1510, 1280,
#        1320, 1150, 1547, 1310, 1130, 1680,  845,  780,  770, 1035, 1015,
#         830, 1195, 1285,  915, 1515,  990, 1235, 1095,  920,  880, 1105,
#        1020,  760,  795,  680,  885, 1080,  985, 1060, 1260, 1265, 1190,
#        1375, 1120,  970, 1270,  520,  450,  630,  420,  355,  678,  502,
#         510,  750,  718,  870,  410,  472,  886,  428,  392,  500,  463,
#         278,  714,  515,  495,  562,  625,  480,  290,  345,  937,  660,
#         406,  710,  438,  415,  672,  315,  488,  312,  325,  607,  434,
#         385,  407,  372,  564,  465,  365,  380,  378,  352,  466,  342,
#         580,  530,  560,  600,  650,  695,  720,  590,  550,  855,  425,
#         675,  640,  725,  620,  570,  615,  685,  470,  740,  835,  840],
#       dtype=int64)

# %%
len(df['Alcohol'].unique())
# Out:
# 126

# %%
df['Alcohol'].size
# Out:
# 178

# %%
df.shape
# Out:
# (178, 13)
